# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
songs = pd.read_csv('songs.csv')
songs.head()
# Out:
#                               Track URI  \
# 0  spotify:track:1XAZlnVtthcDZt2NI1Dtxo
# 1  spotify:track:6a8GbQIlV8HBUW3c6Uk9PH
# 2  spotify:track:70XtWbcVZcpaOddJftMcVi
# 3  spotify:track:1NXUWyPJk5kO6DQJ5t7bDu
# 4  spotify:track:72WZtWs6V7uu3aMgMmEkYe
#
#                                 Track Name  \
# 0  Justified & Ancient - Stand by the Jams
# 1          I Know You Want Me (Calle Ocho)
# 2       From the Bottom of My Broken Heart
# 3         Apeman - 2014 Remastered Version
# 4       You Can't Always Get What You Want
#
#                            Artist URI(s)      Artist Name(s)  \
# 0  spotify:artist:6dYrdRlNZSKaVxYg5IrvCH             The KLF
# 1  spotify:artist:0TnOYISbd1XYRBk9myaseg             Pitbull
# 2  spotify:artist:26dSoYclwsYLMAKD3tpOr4      Britney Spears
# 3  spotify:artist:1SQRv42e4PjEYfPhS0Tk9E           The Kinks
# 4  spotify:artist:22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones
#
#                               Album URI  \
# ...

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Track URI             9999 non-null   object
#  1   Track Name            9998 non-null   object
#  2   Artist URI(s)         9997 non-null   object
#  3   Artist Name(s)        9998 non-null   object
#  4   Album URI             9997 non-null   object
#  5   Album Name            9998 non-null   object
#  6   Album Artist URI(s)   9997 non-null   object
#  7   Album Artist Name(s)  9997 non-null   object
#  8   Album Release Date    9997 non-null   object
#  9   Album Image URL       9995 non-null   object
#  10  Disc Number           9999 non-null   int64
#  11  Track Number          9999 non-null   int64
#  12  Track Duration (ms)   9999 non-null   int64
#  13  Track Preview URL     7102 non-null   object
#  14  Explicit              9999 non-null   bool
# ...

# %%
songs.describe()
# Out:
#        Disc Number  Track Number  Track Duration (ms)   Popularity  \
# count  9999.000000   9999.000000         9.999000e+03  9999.000000
# mean      1.035104      4.957096         2.248150e+05    37.624662
# std       0.327856      5.502810         5.410012e+04    29.460808
# min       0.000000      0.000000         0.000000e+00     0.000000
# 25%       1.000000      1.000000         1.925795e+05     0.000000
# 50%       1.000000      3.000000         2.199060e+05    42.000000
# 75%       1.000000      7.000000         2.502600e+05    64.000000
# max      15.000000     93.000000         1.561133e+06    98.000000
#
#        Danceability       Energy          Key     Loudness         Mode  \
# count   9997.000000  9997.000000  9997.000000  9997.000000  9997.000000
# mean       0.607925     0.683281     5.167750    -7.269217     0.698410
# std        0.145869     0.191131     3.578392     3.281731     0.458971
# min        0.000000     0.000020     0.000000   -29.368000     0.000000
# ...

# %%
songs['Artist Genres']
# Out:
# 0             acid house,ambient house,big beat,hip house
# 1                             dance pop,miami hip hop,pop
# 2                                           dance pop,pop
# 3       album rock,art rock,british invasion,classic r...
# 4           album rock,british invasion,classic rock,rock
#                               ...
# 9994    german dance,pop dance,pop edm,uk dance,pop da...
# 9995                    australian dance,melbourne bounce
# 9996    disco house,vocal house,dance pop,europop,new ...
# 9997    big room,brostep,dutch edm,edm,house,pop dance...
# 9998    australian dance,australian pop,dance pop,euro...
# Name: Artist Genres, Length: 9999, dtype: object

# %%
songs.plot(kind='scatter', x="Popularity", y="Tempo", alpha=0.4)
# Out:
# <AxesSubplot:xlabel='Popularity', ylabel='Tempo'>

# %%
songs.plot(kind='scatter', x="Popularity", y="Danceability", alpha=0.4)
# Out:
# <AxesSubplot:xlabel='Popularity', ylabel='Danceability'>

# %%
songs.plot(kind='scatter', x="Popularity", y="Track Duration (ms)", alpha=0.4)
# Out:
# <AxesSubplot:xlabel='Popularity', ylabel='Track Duration (ms)'>

# %%
import seaborn as sns

# %%
sns.scatterplot(x="Popularity", y="Tempo", data=songs)
# Out:
# <AxesSubplot:xlabel='Popularity', ylabel='Tempo'>

# %%
songs.columns = songs.columns.str.replace(" ", "_").str.lower()

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_uri             9999 non-null   object
#  1   track_name            9998 non-null   object
#  2   artist_uri(s)         9997 non-null   object
#  3   artist_name(s)        9998 non-null   object
#  4   album_uri             9997 non-null   object
#  5   album_name            9998 non-null   object
#  6   album_artist_uri(s)   9997 non-null   object
#  7   album_artist_name(s)  9997 non-null   object
#  8   album_release_date    9997 non-null   object
#  9   album_image_url       9995 non-null   object
#  10  disc_number           9999 non-null   int64
#  11  track_number          9999 non-null   int64
#  12  track_duration_(ms)   9999 non-null   int64
#  13  track_preview_url     7102 non-null   object
#  14  explicit              9999 non-null   bool
# ...

# %%
songs.columns = songs.columns.str.replace("\(s\)", "", regex=True)

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   track_uri            9999 non-null   object
#  1   track_name           9998 non-null   object
#  2   artist_uri           9997 non-null   object
#  3   artist_name          9998 non-null   object
#  4   album_uri            9997 non-null   object
#  5   album_name           9998 non-null   object
#  6   album_artist_uri     9997 non-null   object
#  7   album_artist_name    9997 non-null   object
#  8   album_release_date   9997 non-null   object
#  9   album_image_url      9995 non-null   object
#  10  disc_number          9999 non-null   int64
#  11  track_number         9999 non-null   int64
#  12  track_duration_(ms)  9999 non-null   int64
#  13  track_preview_url    7102 non-null   object
#  14  explicit             9999 non-null   bool
# ...

# %%
songs.columns = songs.columns.str.replace("\(ms\)", "", regex=True)

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_uri           9999 non-null   object
#  1   track_name          9998 non-null   object
#  2   artist_uri          9997 non-null   object
#  3   artist_name         9998 non-null   object
#  4   album_uri           9997 non-null   object
#  5   album_name          9998 non-null   object
#  6   album_artist_uri    9997 non-null   object
#  7   album_artist_name   9997 non-null   object
#  8   album_release_date  9997 non-null   object
#  9   album_image_url     9995 non-null   object
#  10  disc_number         9999 non-null   int64
#  11  track_number        9999 non-null   int64
#  12  track_duration_     9999 non-null   int64
#  13  track_preview_url   7102 non-null   object
#  14  explicit            9999 non-null   bool
# ...

# %%
songs.duplicated().sum()
# Out:
# 48

# %%
songs.drop_duplicates(inplace=True)

# %%
songs.drop_duplicates(subset=['track_name'], inplace=True)

# %%
songs.shape
# Out:
# (8259, 35)

# %%
songs.isnull().sum()
# Out:
# track_uri                0
# track_name               1
# artist_uri               2
# artist_name              1
# album_uri                2
# album_name               1
# album_artist_uri         2
# album_artist_name        2
# album_release_date       2
# album_image_url          4
# disc_number              0
# track_number             0
# track_duration_          0
# track_preview_url     2295
# explicit                 0
# popularity               0
# isrc                     3
# added_by                 0
# added_at                 0
# artist_genres          500
# danceability             2
# energy                   2
# key                      2
# loudness                 2
# mode                     2
# speechiness              2
# acousticness             2
# instrumentalness         2
# liveness                 2
# valence                  2
# tempo                    2
# time_signature           2
# album_genres          8259
# label                    5
# ...

# %%
songs.shape
# Out:
# (8259, 35)

# %%
songs = songs[['track_name', 'artist_name', 'album_name','album_artist_name','album_release_date', 'artist_genres', 'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'track_duration_']]

# %%
songs.head()
# Out:
#                                 track_name         artist_name  \
# 0  Justified & Ancient - Stand by the Jams             The KLF
# 1          I Know You Want Me (Calle Ocho)             Pitbull
# 2       From the Bottom of My Broken Heart      Britney Spears
# 3         Apeman - 2014 Remastered Version           The Kinks
# 4       You Can't Always Get What You Want  The Rolling Stones
#
#                                           album_name   album_artist_name  \
# 0                                   Songs Collection             The KLF
# 1                     Pitbull Starring In Rebelution             Pitbull
# 2     ...Baby One More Time (Digital Deluxe Version)      Britney Spears
# 3  Lola vs. Powerman and the Moneygoround, Pt. On...           The Kinks
# 4                                       Let It Bleed  The Rolling Stones
#
#   album_release_date                                      artist_genres  \
# ...

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8259 entries, 0 to 9997
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_name          8258 non-null   object
#  1   artist_name         8258 non-null   object
#  2   album_name          8258 non-null   object
#  3   album_artist_name   8257 non-null   object
#  4   album_release_date  8257 non-null   object
#  5   artist_genres       7759 non-null   object
#  6   popularity          8259 non-null   int64
#  7   danceability        8257 non-null   float64
#  8   energy              8257 non-null   float64
#  9   key                 8257 non-null   float64
#  10  loudness            8257 non-null   float64
#  11  mode                8257 non-null   float64
#  12  speechiness         8257 non-null   float64
#  13  acousticness        8257 non-null   float64
#  14  instrumentalness    8257 non-null   float64
# ...

# %%
songs.isnull().sum()
# Out:
# track_name              1
# artist_name             1
# album_name              1
# album_artist_name       2
# album_release_date      2
# artist_genres         500
# popularity              0
# danceability            2
# energy                  2
# key                     2
# loudness                2
# mode                    2
# speechiness             2
# acousticness            2
# instrumentalness        2
# liveness                2
# valence                 2
# tempo                   2
# track_duration_         0
# dtype: int64

# %%
songs.dropna(subset=['track_name'], inplace=True)
# Out:
# c:\Users\Dush\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
songs.isnull().sum()
# Out:
# track_name              0
# artist_name             0
# album_name              0
# album_artist_name       2
# album_release_date      2
# artist_genres         499
# popularity              0
# danceability            2
# energy                  2
# key                     2
# loudness                2
# mode                    2
# speechiness             2
# acousticness            2
# instrumentalness        2
# liveness                2
# valence                 2
# tempo                   2
# track_duration_         0
# dtype: int64

# %%
songs['album_release_date'] = pd.to_datetime(songs['album_release_date'], format="%Y-%m-%d")
# Out:
# c:\Users\Dush\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
songs['year'] = songs['album_release_date'].dt.year
songs['month'] = songs['album_release_date'].dt.month
songs['day'] = songs['album_release_date'].dt.day
# Out:
# c:\Users\Dush\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\Users\Dush\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\Dush\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
songs.drop(columns=['album_release_date'], inplace=True)
# Out:
# c:\Users\Dush\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8258 entries, 0 to 9997
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_name         8258 non-null   object
#  1   artist_name        8258 non-null   object
#  2   album_name         8258 non-null   object
#  3   album_artist_name  8256 non-null   object
#  4   artist_genres      7759 non-null   object
#  5   popularity         8258 non-null   int64
#  6   danceability       8256 non-null   float64
#  7   energy             8256 non-null   float64
#  8   key                8256 non-null   float64
#  9   loudness           8256 non-null   float64
#  10  mode               8256 non-null   float64
#  11  speechiness        8256 non-null   float64
#  12  acousticness       8256 non-null   float64
#  13  instrumentalness   8256 non-null   float64
#  14  liveness           8256 non-null   float64
# ...

# %%
#convert duration to minutes
songs['track_duration_'] = songs['track_duration_']/60000
# Out:
# c:\Users\Dush\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
songs['track_duration_']
# Out:
# 0       3.604500
# 1       3.952000
# 2       5.208883
# 3       3.890000
# 4       7.478667
#           ...
# 9993    4.752883
# 9994    2.763333
# 9995    2.944000
# 9996    3.793650
# 9997    2.557367
# Name: track_duration_, Length: 8258, dtype: float64

# %%
num_columns = ['popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'track_duration_']

# %%
for col in num_columns:
    songs[col] = songs[col].astype(str)
# Out:
# c:\Users\Dush\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
songs['artist_genres'] = songs['artist_genres'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
songs['artist_name'] = songs['artist_name'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
songs['album_artist_name'] = songs['album_artist_name'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
songs['album_name'] = songs['album_name'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
# Out:
# c:\Users\Dush\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# c:\Users\Dush\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# ...

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8258 entries, 0 to 9997
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_name         8258 non-null   object
#  1   artist_name        8258 non-null   object
#  2   album_name         8258 non-null   object
#  3   album_artist_name  8256 non-null   object
#  4   artist_genres      7759 non-null   object
#  5   popularity         8258 non-null   object
#  6   danceability       8258 non-null   object
#  7   energy             8258 non-null   object
#  8   key                8258 non-null   object
#  9   loudness           8258 non-null   object
#  10  mode               8258 non-null   object
#  11  speechiness        8258 non-null   object
#  12  acousticness       8258 non-null   object
#  13  instrumentalness   8258 non-null   object
#  14  liveness           8258 non-null   object
#  15  valence            8258 non-null   object
# ...

# %%
#convert to strings again
num_columns = ['popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'track_duration_', 'day', 'year', 'month']

for col in num_columns:
    songs[col] = songs[col].astype(str)
# Out:
# c:\Users\Dush\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
songs['track_duration_'] = songs['track_duration_'].astype(str)
# Out:
# c:\Users\Dush\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8258 entries, 0 to 9997
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_name         8258 non-null   object
#  1   artist_name        8258 non-null   object
#  2   album_name         8258 non-null   object
#  3   album_artist_name  8256 non-null   object
#  4   artist_genres      7759 non-null   object
#  5   popularity         8258 non-null   object
#  6   danceability       8258 non-null   object
#  7   energy             8258 non-null   object
#  8   key                8258 non-null   object
#  9   loudness           8258 non-null   object
#  10  mode               8258 non-null   object
#  11  speechiness        8258 non-null   object
#  12  acousticness       8258 non-null   object
#  13  instrumentalness   8258 non-null   object
#  14  liveness           8258 non-null   object
#  15  valence            8258 non-null   object
# ...

# %%
songs['artist_genres'].astype(str)
# Out:
# 0             acid house,ambient house,big beat,hip house
# 1                             dance pop,miami hip hop,pop
# 2                                           dance pop,pop
# 3       album rock,art rock,british invasion,classic r...
# 4           album rock,british invasion,classic rock,rock
#                               ...
# 9993                                        german techno
# 9994    german dance,pop dance,pop edm,uk dance,pop da...
# 9995                    australian dance,melbourne bounce
# 9996    disco house,vocal house,dance pop,europop,new ...
# 9997    big room,brostep,dutch edm,edm,house,pop dance...
# Name: artist_genres, Length: 8258, dtype: object

# %%
songs = songs.astype(str)

# %%
#create a new column with all the features
songs['features'] = songs[['artist_name', 'album_name','album_artist_name','artist_genres', 'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'track_duration_', 'day', 'year', 'month']].agg(' '.join, axis=1)

# %%
songs['features'].iloc[0]
# Out:
# 'The KLF Songs Collection The KLF acid house,ambient house,big beat,hip house 0 0.617 0.872 8.0 -12.305 1.0 0.048 0.0158 0.112 0.408 0.504 111.458 3.6045 3.0 1992.0 8.0'

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()

def stem_features(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))
    
    return " ".join(y)

# %%
songs['features'] = songs['features'].apply(stem_features)

# %%
songs['features'].iloc[0]
# Out:
# 'the klf song collect the klf acid house,ambi house,big beat,hip hou 0 0.617 0.872 8.0 -12.305 1.0 0.048 0.0158 0.112 0.408 0.504 111.458 3.6045 3.0 1992.0 8.0'

# %%
cv = CountVectorizer(max_features=5000, stop_words='english')
vectors = cv.fit_transform(songs['features'])

# %%
vectors
# Out:
# <8258x5000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 172055 stored elements in Compressed Sparse Row format>

# %%
similarity = cosine_similarity(vectors, dense_output=False)

# %%
similarity
# Out:
# <8258x8258 sparse matrix of type '<class 'numpy.float64'>'
# 	with 41038576 stored elements in Compressed Sparse Row format>

# %%
def recommend(title, df, similarity_matrix, count_vectorizer):
    title_index = songs[songs['track_name'] == title]

    if len(title_index) == 0:
        print("Song Not Found")
        return

    title_index = title_index.index[0]  
    distances = similarity[title_index]

    title_list = sorted(list(enumerate(distances.todense().tolist()[0])), reverse=True, key=lambda x: x[1])[1:11]

    for i in title_list:
        print(df.iloc[i[0]]['track_name'] + " by " + df.iloc[i[0]]['artist_name'])

# %%
recommend(songs['track_name'].iloc[80], songs, similarity, cv)
# Out:
# Stay (with Alessia Cara) by Zedd, Alessia Cara
# Another Place by Bastille, Alessia Cara
# Lost In Japan - Remix by Shawn Mendes, Zedd
# I Want You To Know by Zedd, Selena Gomez
# How Far I'll Go - From "Moana" by Alessia Cara
# Scars To Your Beautiful by Alessia Cara
# Here by Alessia Cara
# 1-800-273-8255 by Logic, Alessia Cara, Khalid
# Clarity by Zedd, Foxes
# Stay The Night - Featuring Hayley Williams Of Paramore by Zedd, Hayley Williams
